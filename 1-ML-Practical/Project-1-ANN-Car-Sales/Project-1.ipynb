# %% [raw]
# This Machine learning models predicts how much costumer are willing for a car based on the below attributes:
# Costumer Name
# Costumer e-mail
# Country
# Age
# Annual Salary
# Credit Card Debit
# Net Worth

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset
car_df = pd.read_csv("Car_Purchasing_Data.csv'
